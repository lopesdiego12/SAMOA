# %% [markdown]
# # OzaBagAdwin + AdaptiveBagging - Agrawal

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Carregar as bases
df_OBA_Agra = pd.read_csv("../Exercícios/BagAdwin_Agra.txt")
df_AB_Agra = pd.read_csv("../database/output/exe_agra_AB.txt")

# %%
df_OBA_Agra.describe()
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                     100.000000                     100.000000
# mean                    50500.000000                       3.747650
# std                     29011.491976                       2.428875
# min                      1000.000000                       0.061777
# 25%                     25750.000000                       1.750707
# 50%                     50500.000000                       3.323886
# 75%                     75250.000000                       5.565085
# max                    100000.000000                       8.856452
#
#        model cost (RAM-Hours)  classified instances  \
# count            1.000000e+02            100.000000
# mean             1.103584e-06          50500.000000
# std              1.032641e-06          29011.491976
# min              2.227724e-09           1000.000000
# 25%              3.739069e-07          25750.000000
# ...

# %%
df_AB_Agra.describe()
# Out:
#        classified instances  classifications correct (percent)  \
# count            100.000000                         100.000000
# mean           50500.000000                          69.768392
# std            29011.491976                           6.720711
# min             1000.000000                          44.300000
# 25%            25750.000000                          64.690625
# 50%            50500.000000                          69.441784
# 75%            75250.000000                          75.792974
# max           100000.000000                          79.244000
#
#        Kappa Statistic (percent)  Kappa Temporal Statistic (percent)
# count                 100.000000                          100.000000
# mean                   39.536867                           69.562819
# std                    13.441411                            6.785330
# min                   -11.400000                           44.300000
# ...

# %%
# Plotando o gráfico do gerador AgrawalGenerator.
plt.figure(figsize=(10, 5))
plt.plot(df_OBA_Agra['learning evaluation instances'], df_OBA_Agra['classifications correct (percent)'], label='OzaBagAdwin')
plt.plot(df_AB_Agra['classified instances'], df_AB_Agra['classifications correct (percent)'], label='AdaptativeBagging')
plt.axvspan(15000, 25000, color='red', alpha=0.5)
plt.xlim(0, 100000)

# Add the legend with some customizations.
legend = plt.legend(loc='lower right', shadow=True)

# The frame is matplotlib.patches.Rectangle instance surrounding the legend.
frame = legend.get_frame()
frame.set_facecolor('0.90')

# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
    
for label in legend.get_lines():
    label.set_linewidth(1.5)

# Plot chart.
plt.show()

# %% [markdown]
# # HoeffdingTree + VerticalHoeffdingTree - Agrawal

# %%
df_HT_Agra = pd.read_csv("../Exercícios/HoeffdingTree_Agra.txt")
df_VHT_Agra = pd.read_csv("../database/output/exe_agra_VHT.txt")

# %%
df_HT_Agra.describe()
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                     100.000000                     100.000000
# mean                    50500.000000                       1.085020
# std                     29011.491976                       0.525694
# min                      1000.000000                       0.071190
# 25%                     25750.000000                       0.630046
# 50%                     50500.000000                       1.162712
# 75%                     75250.000000                       1.523111
# max                    100000.000000                       1.934529
#
#        model cost (RAM-Hours)  classified instances  \
# count            1.000000e+02            100.000000
# mean             4.777631e-08          50500.000000
# std              3.766619e-08          29011.491976
# min              8.663344e-11           1000.000000
# 25%              1.001305e-08          25750.000000
# ...

# %%
df_VHT_Agra.describe()
# Out:
#        classified instances  classifications correct (percent)  \
# count            100.000000                         100.000000
# mean           50500.000000                          62.671075
# std            29011.491976                          13.660943
# min             1000.000000                           0.000000
# 25%            25750.000000                          58.388214
# 50%            50500.000000                          63.841225
# 75%            75250.000000                          71.812447
# max           100000.000000                          76.228000
#
#        Kappa Statistic (percent)  Kappa Temporal Statistic (percent)
# count                 100.000000                          100.000000
# mean                   25.342214                           62.435166
# std                    27.321890                           13.653722
# min                  -100.000000                            0.000000
# ...

# %%
# Plotando o gráfico do gerador AgrawalGenerator.
plt.figure(figsize=(10, 5))
plt.plot(df_HT_Agra['learning evaluation instances'], df_HT_Agra['classifications correct (percent)'], label='HoeffdingTree')
plt.plot(df_VHT_Agra['classified instances'], df_VHT_Agra['classifications correct (percent)'], label='VerticalHoeffdingTree')
plt.axvspan(15000, 30000, color='red', alpha=0.5)
plt.xlim(0, 100000)

# Add the legend with some customizations.
legend = plt.legend(loc='lower right', shadow=True)

# The frame is matplotlib.patches.Rectangle instance surrounding the legend.
frame = legend.get_frame()
frame.set_facecolor('0.90')

# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
    
for label in legend.get_lines():
    label.set_linewidth(1.5)

# Plot chart.
plt.show()

# %% [markdown]
# # OzaBagAdwin + AdaptiveBagging - SEA

# %%
df_OBA_Sea = pd.read_csv("../Exercícios/BagAdwin_SEA.txt") 
df_AB_Sea = pd.read_csv("../database/output/exe_sea_AB.txt")

# %%
df_OBA_Sea.describe()
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                     100.000000                     100.000000
# mean                    50500.000000                       2.289126
# std                     29011.491976                       1.461398
# min                      1000.000000                       0.061447
# 25%                     25750.000000                       1.007961
# 50%                     50500.000000                       2.140551
# 75%                     75250.000000                       3.499115
# max                    100000.000000                       5.046127
#
#        model cost (RAM-Hours)  classified instances  \
# count            1.000000e+02            100.000000
# mean             2.107261e-07          50500.000000
# std              1.810153e-07          29011.491976
# min              1.753678e-09           1000.000000
# 25%              5.481534e-08          25750.000000
# ...

# %%
df_AB_Sea.describe()
# Out:
#        classified instances  classifications correct (percent)  \
# count            100.000000                         100.000000
# mean           50500.000000                          79.011317
# std            29011.491976                           7.252936
# min             1000.000000                          50.500000
# 25%            25750.000000                          78.486500
# 50%            50500.000000                          81.672784
# 75%            75250.000000                          83.255316
# max           100000.000000                          84.297000
#
#        Kappa Statistic (percent)  Kappa Temporal Statistic (percent)
# count                 100.000000                          100.000000
# mean                   57.888219                           74.335070
# std                    14.856025                            8.746232
# min                    -1.387758                           39.927184
# ...

# %%
# Plotando o gráfico do gerador AgrawalGenerator.
plt.figure(figsize=(10, 5))
plt.plot(df_OBA_Sea['learning evaluation instances'], df_OBA_Sea['classifications correct (percent)'], label='OzaBagAdwin')
plt.plot(df_AB_Sea['classified instances'], df_AB_Sea['classifications correct (percent)'], label='AdaptiveBagging')
plt.xlim(0, 100000)

# Add the legend with some customizations.
legend = plt.legend(loc='lower right', shadow=True)

# The frame is matplotlib.patches.Rectangle instance surrounding the legend.
frame = legend.get_frame()
frame.set_facecolor('0.90')

# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
    
for label in legend.get_lines():
    label.set_linewidth(1.5)

# Plot chart.
plt.show()

# %% [markdown]
# # HoeffdingTree + VerticalHoeffdingTree - SEA

# %%
df_HT_Sea = pd.read_csv("../Exercícios/HoeffdingTree_SEA.txt")
df_VHT_Sea = pd.read_csv("../database/output/exe_sea_VHT.txt")

# %%
df_HT_Sea.describe()
# Out:
#        learning evaluation instances  evaluation time (cpu seconds)  \
# count                     100.000000                     100.000000
# mean                    50500.000000                       0.319661
# std                     29011.491976                       0.151412
# min                      1000.000000                       0.021055
# 25%                     25750.000000                       0.216735
# 50%                     50500.000000                       0.327535
# 75%                     75250.000000                       0.442476
# max                    100000.000000                       0.572986
#
#        model cost (RAM-Hours)  classified instances  \
# count            1.000000e+02            100.000000
# mean             1.764644e-09          50500.000000
# std              1.445080e-09          29011.491976
# min              1.024036e-11           1000.000000
# 25%              5.977754e-10          25750.000000
# ...

# %%
df_VHT_Sea.describe()
# Out:
#        classified instances  classifications correct (percent)  \
# count            100.000000                         100.000000
# mean           50500.000000                          77.500355
# std            29011.491976                           7.026078
# min             1000.000000                          50.650000
# 25%            25750.000000                          76.388154
# 50%            50500.000000                          80.144118
# 75%            75250.000000                          81.679237
# max           100000.000000                          82.820000
#
#        Kappa Statistic (percent)  Kappa Temporal Statistic (percent)
# count                 100.000000                          100.000000
# mean                   54.856285                           72.484755
# std                    14.408755                            8.468296
# min                    -0.799816                           40.109223
# ...

# %%
# Plotando o gráfico do gerador AgrawalGenerator.
plt.figure(figsize=(10,5))
plt.plot(df_HT_Sea['learning evaluation instances'], df_HT_Sea['classifications correct (percent)'], label='HoeffdingTree')
plt.plot(df_VHT_Sea['classified instances'], df_VHT_Sea['classifications correct (percent)'], label='VerticalHoeffdingTree')
plt.xlim(0, 100000)

# Add the legend with some customizations.
legend = plt.legend(loc='lower right', shadow=True)

# The frame is matplotlib.patches.Rectangle instance surrounding the legend.
frame = legend.get_frame()
frame.set_facecolor('0.90')

# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('large')
    
for label in legend.get_lines():
    label.set_linewidth(1.5)

# Plot chart.
plt.show()

# %% [markdown]
# https://github.com/Oracy/SAMOA/blob/master/Exerc%C3%ADcios/Trabalho_Jean.ipynb
